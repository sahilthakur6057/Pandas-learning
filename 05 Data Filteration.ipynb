# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# #### SELECTING SINGLE COLUMN

# %%
df["pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# #### SELECTING MULTIPLE COLUMNS

# %%
df[["survived","age","who"]][0:31]
# Out:
#     survived   age    who
# 0          0  22.0    man
# 1          1  38.0  woman
# 2          1  26.0  woman
# 3          1  35.0  woman
# 4          0  35.0    man
# 5          0   NaN    man
# 6          0  54.0    man
# 7          0   2.0  child
# 8          1  27.0  woman
# 9          1  14.0  child
# 10         1   4.0  child
# 11         1  58.0  woman
# 12         0  20.0    man
# 13         0  39.0    man
# 14         0  14.0  child
# 15         1  55.0  woman
# 16         0   2.0  child
# 17         1   NaN    man
# 18         0  31.0  woman
# 19         1   NaN  woman
# 20         0  35.0    man
# 21         1  34.0    man
# 22         1  15.0  child
# 23         1  28.0    man
# 24         0   8.0  child
# 25         1  38.0  woman
# 26         0   NaN    man
# 27         0  19.0    man
# 28         1   NaN  woman
# 29         0   NaN    man
# 30         0  40.0    man

# %% [markdown]
# #### SELECTING A VALUE

# %%
df['embark_town'][0:20]
# Out:
# 0     Southampton
# 1       Cherbourg
# 2     Southampton
# 3     Southampton
# 4     Southampton
# 5      Queenstown
# 6     Southampton
# 7     Southampton
# 8     Southampton
# 9       Cherbourg
# 10    Southampton
# 11    Southampton
# 12    Southampton
# 13    Southampton
# 14    Southampton
# 15    Southampton
# 16     Queenstown
# 17    Southampton
# 18    Southampton
# 19      Cherbourg
# Name: embark_town, dtype: object

# %%
df['embark_town'][20]
# Out:
# 'Southampton'

# %% [markdown]
# #### SELECTING NUMBER OF ROWS

# %%
df.head() ## yeh upr ke 5 number apne app utha leta h inko change bhi kr skte h andr number likh kr
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()  ## yeh niche ke 5 number apne app utha leta h inko change bhi kr skte h andr number likh kr
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 327         1       2  female  36.0      0      0   13.0000        S  Second
# 107         1       3    male   NaN      0      0    7.7750        S   Third
# 374         0       3  female   3.0      3      1   21.0750        S   Third
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 87          0       3    male   NaN      0      0    8.0500        S   Third
# 439         0       2    male  31.0      0      0   10.5000        S  Second
# 212         0       3    male  22.0      0      0    7.2500        S   Third
# 353         0       3    male  25.0      1      0   17.8000        S   Third
# 596         1       2  female   NaN      0      0   33.0000        S  Second
# 836         0       3    male  21.0      0      0    8.6625        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 327  woman       False    D  Southampton   yes   True
# ...

# %%
df[0::2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[0:20]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# ### LOC AND ILOC

# %% [markdown]
# #### The main difference between loc and iloc in pandas is that loc is label-based indexing (using row and column names).
# #### While iloc is integer position-based indexing (using row and column numbers).

# %%
d = {
    'name':['Sahil','Happy', 'Rohit','Vansh'],
    'age' :[30,20,50,25]
}

# %%
df = pd.DataFrame(d,index=['A','B','C','D'])

# %%
df
# Out:
#     name  age
# A  Sahil   30
# B  Happy   20
# C  Rohit   50
# D  Vansh   25

# %% [markdown]
# ##### FILTERING BY INDEX NAME

# %%
df.loc['A']
# Out:
# name    Sahil
# age        30
# Name: A, dtype: object

# %% [markdown]
# ##### FILTERING BY INDEX NUMBER

# %%
df.iloc[1]
# Out:
# name    Happy
# age        20
# Name: B, dtype: object

# %% [markdown]
# ##### INDEXING SLICING  (ROW , COLUMN , VALUE)

# %%
df
# Out:
#     name  age
# A  Sahil   30
# B  Happy   20
# C  Rohit   50
# D  Vansh   25

# %%
 df.iloc[1:,0]
# Out:
# B    Happy
# C    Rohit
# D    Vansh
# Name: name, dtype: object

# %%
df.iloc[2:,1]
# Out:
# C    50
# D    25
# Name: age, dtype: int64

# %%
df = sns.load_dataset('anagrams')

# %%
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %% [markdown]
# #### This is use to convert any column into index

# %%
df.set_index('subidr')
# Out:
#           attnr  num1  num2  num3
# subidr
# 1       divided     2   4.0     7
# 2       divided     3   4.0     5
# 3       divided     3   5.0     6
# 4       divided     5   7.0     5
# 5       divided     4   5.0     8
# 6       divided     5   5.0     6
# 7       divided     5   4.5     6
# 8       divided     5   7.0     8
# 9       divided     2   3.0     7
# 10      divided     6   5.0     6
# 11      focused     6   5.0     6
# 12      focused     8   9.0     8
# 13      focused     6   5.0     9
# 14      focused     8   8.0     7
# 15      focused     8   8.0     7
# 16      focused     6   8.0     7
# 17      focused     7   7.0     6
# 18      focused     7   8.0     6
# 19      focused     5   6.0     6
# 20      focused     6   6.0     5

# %%
d = {
    'id'  : ['A','B','C','D','E','F','G','H'],
    'name':['Sahil','Happy','Rohit','Vansh','Ankit','Priya','Neha','Arjun'],
    'age' : [30,20,50,25,28,32,22,40]
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#   id   name  age
# 0  A  Sahil   30
# 1  B  Happy   20
# 2  C  Rohit   50
# 3  D  Vansh   25
# 4  E  Ankit   28
# 5  F  Priya   32
# 6  G   Neha   22
# 7  H  Arjun   40

# %%
df.set_index('id', inplace=True)

# %%
df
# Out:
#      name  age
# id
# A   Sahil   30
# B   Happy   20
# C   Rohit   50
# D   Vansh   25
# E   Ankit   28
# F   Priya   32
# G    Neha   22
# H   Arjun   40

# %%
df.loc[['E','F'],'name']
# Out:
# id
# E    Ankit
# F    Priya
# Name: name, dtype: object

# %%
df = sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.iloc[0:11, 0:8]
# Out:
#                 pickup             dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5  2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6  2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7  2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8  2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9  2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
# 10 2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.00
#
#     tolls  total
# 0     0.0  12.95
# ...

# %% [markdown]
# #### FILTERING DATA THROUGH BOOLEAN MANIPULATION

# %%
df[df['total'] > 50]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 42   2019-03-30 23:59:14 2019-03-30 23:59:17           1      0.00  80.0
# 56   2019-03-05 17:57:00 2019-03-05 18:45:25           2     19.59  52.0
# 111  2019-03-15 10:56:56 2019-03-15 11:37:02           1     11.93  39.5
# 128  2019-03-06 19:29:56 2019-03-06 20:08:36           1     10.80  36.0
# 162  2019-03-06 17:36:48 2019-03-06 18:43:39           2     17.10  52.0
# ...                  ...                 ...         ...       ...   ...
# 6362 2019-03-08 03:34:43 2019-03-08 04:20:37           1     21.37  62.5
# 6393 2019-03-10 18:33:13 2019-03-10 19:32:38           1      0.00  71.2
# 6398 2019-03-17 13:07:29 2019-03-17 13:51:56           1     18.39  50.5
# 6400 2019-03-22 17:41:23 2019-03-22 18:26:00           1     13.77  43.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
#
#         tip  tolls   total   color      payment                pickup_zone  \
# ...

# %%
df[df['color'] == 'green']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 5451 2019-03-24 15:05:22 2019-03-24 15:26:32           1      2.29  15.0
# 5452 2019-03-14 22:04:04 2019-03-14 22:10:00           1      0.80   5.5
# 5453 2019-03-29 18:12:27 2019-03-29 18:20:40           1      1.51   7.5
# 5454 2019-03-06 11:11:33 2019-03-06 11:15:15           1      0.45   4.5
# 5455 2019-03-04 18:43:53 2019-03-04 18:46:50           1      0.61   4.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total  color      payment          pickup_zone  \
# ...

# %%
df[(df['color'] == 'green') & (df['total'] > 50)]
# Out:
#                   pickup             dropoff  passengers  distance    fare  \
# 5457 2019-03-17 18:02:49 2019-03-17 18:33:14           1     12.79   38.50
# 5458 2019-03-30 20:59:25 2019-03-30 21:46:52           1     24.48   63.53
# 5463 2019-03-22 14:56:45 2019-03-22 16:09:50           1     18.91   61.00
# 5495 2019-03-20 07:03:00 2019-03-20 07:54:47           1     16.71   50.74
# 5567 2019-03-07 00:28:57 2019-03-07 02:02:55           1     25.51   93.50
# 5648 2019-03-19 14:21:35 2019-03-19 15:51:28           2     33.46  150.00
# 5654 2019-03-30 22:13:58 2019-03-30 22:47:41           1     18.89   44.20
# 5678 2019-03-15 20:34:02 2019-03-15 20:34:10           1      0.00   52.00
# 5702 2019-03-23 14:29:29 2019-03-23 15:21:09           1     14.47   46.50
# 5708 2019-03-04 09:42:07 2019-03-04 10:35:59           1     18.60   58.00
# 5728 2019-03-01 17:07:09 2019-03-01 18:05:41           1     21.27   65.59
# ...
